# %%
ENV["JULIA_NUM_THREADS"] = "1"
using Pkg
Pkg.activate("..")
Pkg.instantiate()
# Out:
#   Activating project at `~/AwID/MLP`
# Precompiling project...
#     339.4 ms  ✓ MLP
#   1 dependency successfully precompiled in 1 seconds. 205 already precompiled.

# %%
Pkg.test()
# Out:
#      Testing MLP
#       Status `/tmp/jl_yOFCN4/Project.toml`
#   [5789e2e9] FileIO v1.17.0
#   [587475ba] Flux v0.16.3
# ⌃ [7073ff75] IJulia v1.26.0
# ⌃ [033835bb] JLD2 v0.5.12
#   [8ef0a80b] Languages v0.4.6
#   [7fb77206] MLP v0.0.0 `~/AwID/MLP`
#   [10745b16] Statistics v1.11.1
#   [a2db99b7] TextAnalysis v0.8.2
#   [37e2e46d] LinearAlgebra v1.11.0
#   [9a3f8284] Random v1.11.0
#   [8dfed614] Test v1.11.0
#       Status `/tmp/jl_yOFCN4/Manifest.toml`
#   [621f4979] AbstractFFTs v1.5.0
#   [7d9f7c33] Accessors v0.1.42
#   [79e6a3ab] Adapt v4.3.0
#   [66dad0bd] AliasTables v1.1.3
#   [dce04be8] ArgCheck v2.5.0
#   [a9b6321e] Atomix v1.1.1
#   [198e06fe] BangBang v0.4.4
#   [9718e550] Baselet v0.1.1
#   [d1d4a3ce] BitFlags v0.1.9
#   [082447d4] ChainRules v1.72.3
#   [d360d2e6] ChainRulesCore v1.25.1
#   [944b1d66] CodecZlib v0.7.8
#   [bbf7d656] CommonSubexpressions v0.3.1
#   [34da2185] Compat v4.16.0
#   [a33af91c] CompositionsBase v0.1.2
# ...
